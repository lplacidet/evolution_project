# %%
using Random
using LinearAlgebra
using Statistics
using Plots
import Base.isless

using Cxx, Libdl

# %%
const path_to_lib = pwd()
addHeaderDir(path_to_lib*"/world/", kind=C_System)
cxxinclude("runWorld.h")

# %%
mutable struct Bird
    genes::Array{Float64}
    fitness::Float64
end

function Bird(;dim=5)
    genes = randn(dim)
    fitness = 0.0
    Bird(genes, fitness)
end 

function isless(b1::Bird, b2::Bird)
    b1.fitness < b2.fitness
end
# Out:
# isless (generic function with 45 methods)

# %%
#test
flappy = Bird()
println(flappy)
# Out:
# Bird([-0.15871243804182267, -1.4396166400680228, -0.5348607608161856, -0.03168489396723777, 0.08135429261946328], 0.0)

# %%
cxx"""

static double evaluate_bird(float g1, float g2, float g3, float g4, float g5) {
float ind[5] = {g1,g2,g3,g4,g5};

	const int NRUN = 3;
	auto &g = ind;
	double d = 0;
	for (int r = 0; r < NRUN; ++r) {
		World world;
		world.gen.seed(r * 100);
		while (world.bestiau.vivant) {

            world.update();
            // update inputs
            float birdY = world.bestiau.y;
            float birdVY = world.bestiau.vit;
            float obsX;
            float obsY;
            if (world.obstacles.size() > 0) {
                const auto &o = world.obstacles.front();
                obsY = o.y + world.hauteurPassage * 0.5;
                obsX = o.x / world.W;
            } else {
                obsY = world.H * 0.5;
                obsX = 1000.0;
            }
            double dd = world.dist;
            //if ((g[0]*birdY+g[1]*birdVY+g[2]*obsX+g[3]*obsY)>1.0) world.bestiauUp();
            //if ((g[0]*(birdY-obsY)+g[1]*birdY+g[2]*obsX+g[3]*birdVY)>1.0) world.bestiauUp();
            //if ((g[0]*(birdY-obmsY)+g[1]*birdY+g[2]*obsX+g[3]*birdVY+g[4]*dd)>1.0) world.bestiauUp();
            if ((g[0]*(birdY-obsY)+g[1]*birdY+g[2]*obsX+g[3]*birdVY+g[4]*world.vitesseDefilement)>1.0) world.bestiauUp();
        }
        d += world.dist;
        d -= 0.001*abs(world.bestiau.y-world.obstacles.front().y);
    }
    return d;
}
"""
# Out:
# In file included from /Cxx.cpp:1:
# In[5]:34:20: warning: using integer absolute value function 'abs' when argument is of floating point type
#         d -= 0.001*abs(world.bestiau.y-world.obstacles.front().y);
#                    ^
# In[5]:34:20: note: use function 'std::abs' instead
#         d -= 0.001*abs(world.bestiau.y-world.obstacles.front().y);
#                    ^~~
#                    std::abs
# true

# %%
cpptojulia(g1::Float64, g2::Float64, g3::Float64, g4::Float64, g5::Float64) = @cxx evaluate_bird(g1,g2,g3,g4,g5)
function evaluate_bird(g::Array{Float64})
    cpptojulia(g[1],g[2],g[3],g[4],g[5])
end
# Out:
# evaluate_bird (generic function with 1 method)

# %%
function evaluate!(flappy::Bird)
    g=flappy.genes
    flappy.fitness = evaluate_bird(g)
end
# Out:
# evaluate! (generic function with 1 method)

# %%
# test

flappy = Bird()
println(flappy)
g = flappy.genes
ev = evaluate_bird(g)
println(ev)
evaluate!(flappy)
println(flappy)

println("_____2nd______")
flappy2 = Bird()
flappy2.genes = [-3.72, -0.46, -0.227, -1.90, 0.0] #param pour {deltaY, bY, oX, bVY} >1.0
println(flappy2)
ev2 = evaluate_bird(flappy2.genes)
println(ev2)
evaluate!(flappy2)
println(flappy2)


println("isless ", flappy>flappy2)
println("isless ", flappy<flappy2)
# Out:
# Bird([0.35898035084951496, -1.5447746274842244, 0.40788156760691063, -0.01094106712543263, -0.12818840707579987], 0.0)
# 1.05264
# Bird([0.35898035084951496, -1.5447746274842244, 0.40788156760691063, -0.01094106712543263, -0.12818840707579987], 1.05264)
# _____2nd______
# Bird([-3.72, -0.46, -0.227, -1.9, 0.0], 0.0)
# 330.2594399999938
# Bird([-3.72, -0.46, -0.227, -1.9, 0.0], 330.2594399999938)
# isless false
# isless true

# %% [markdown]
# ## GÈNES DES DIFFÉRENTS RÉSULTATS ##
#
# ##### ES (1,LAMBDA)
# #Paramètres utilisés:
# Npop = 100
# Ngen = 1000
# Sigma = 0.1
#
# #Fitness = 1.052214059349051:
#
# Gènes:[-0.9751542478866444, 0.6447822521046234, 0.18472010365664163, 0.9299106461076789, 0.04787136047161242]
#
# #Fitness = 65.50495491300633:
#
# Gènes: [-2.394991962666485, -0.5765202759152778, 0.36016853841569196, -1.354220550169007, 0.22848930431665287]
#
# #Fitness = 126.24929614014675:
#
# Gènes: [-2.183671863777222, -0.22121912188390788, 0.7951770421705254, -1.580488918636695, -0.015198363809458028]
#
# #Fitness = 358.579500125548:
#
# Gènes: [-4.023728549336323, -0.4065869239407867, -0.2096689009727345, -2.109899423244844, -0.09433223850827027]
#
# ##### CMA-ES
#
# #Fitness = 1.052214059349051:
#
# Gènes:[-1.5261703337096308, 2.845914961592199, -3.3341481445035597, 0.7708780664237068, -0.4744185158073895]
#
# #Fitness = 61.55202543394702:
#
# Gènes: [-35.461495937708534, -7.345074107176794, -2.230862469692626, -4.847917636820603, 0.21309090114557624]
#
#
# #Fitness = 142.47097524567707:
#
# Gènes:[-34.665959001568936, -10.936541213754017, -3.068613186256208, -7.0089754387471634, -0.1884241023887225]
#
#
# #Fitness = 350.92286639693094:
#
# Gènes:Bird([-7.366221371280225, -0.865036352478838, -0.8980783611738886, -2.9588206578520513, -0.2722294660077248]

# %% [markdown]
# #  _________________________ES 1___

# %%
function step_birds(best::Array{Float64};dim=5, npop=50, sigma=0.1, alpha=sigma/10)
    N = randn(npop,dim)
    P = repeat(best, 1, npop)' .+  sigma.* N #[N[i,:].*sigma for i in 1:npop]

    R = zeros(npop)
    for i in eachindex(R)
        R[i] = objective(P[i, :]) #evaluation
    end
    
    
    #println("  R    :", R)
    
    A = (R .- mean(R)) ./ std(R)
    #println("____________________")
    #println(" A :", A)
    #println("____________________")
    #println(" N : ", N[:,1])
    
    test = dot(N[:, 1], A)
    #println(" test :", test)
    if isnan(test)
        println("failed")
    end
    mat = [dot(N[:, i], A) for i in 1:size(N, 2)]
    #println("mat : ", mat)
    #println(alpha/(npop * sigma) .* mat)
    w = alpha/(npop * sigma) .* mat#[dot(N[:, i], A) for i in 1:size(N, dim)]
    #println(" w : ", w)
    best = best .+ w #modification step: changing the center of gravity
    best
end
# Out:
# step_birds (generic function with 1 method)

# %%
function run_es_bird(;Nstep=500, Npop=100, Sigma=0.1)
    dim = 5
    best = randn(dim)
    #best = [-4.991793690362872, -1.0548510731723693, -0.46613776158659587, -2.281903602732939, -0.0011843804167953435]
    #best = [-3.7801608774814435, -0.3807797572729434, -0.1904445735415997, -2.0321882891336522, -0.067457035171137]
    
    println("best initial: ", best)
    first_fitness = evaluate_bird(best)
    println("best initial fitness:", first_fitness)
    
    dist = zeros(Nstep)
    for i in 1:Nstep
        best = step_birds(best, dim=dim, npop=Npop, sigma=Sigma)
        #println("best: ", best)
        #println("best norm: ", norm(best))
        #println("dist max :" , objective(best))
        dist[i] = objective(best)
        #if dist[i]>300
         #   Sigma = 0.01
        #end
    end
    println("best final: ", best)
    println("best final dist: ", objective(best))
    #best
    dist
end
# Out:
# run_es_bird (generic function with 1 method)

# %%
objective = evaluate_bird
Npop = 1000
Ngen = 100
sig = 0.1
res = run_es_bird(Nstep=Ngen, Npop=Npop, Sigma=sig)
distances = res
plot(distances)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness pour l'ES")
# Out:
# best initial: [0.663954879174813, -0.01960526524613806, 0.35702287151168005, -0.07626303186996906, -0.6515111682601555]
# best initial fitness:1.05264
# best final: [0.689290220480107, -0.03502850436167773, 0.31458486849146916, -0.04884295865231143, -0.6226442663414474]
# best final dist: 1.05264

# %%
objective = evaluate_bird
Npop = 200
Ngen = 500
sig = 0.1
res = run_es_bird(Nstep=Ngen, Npop=Npop, Sigma=sig)
distances = res
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness pour l'ES")
distance_histogram = distances

for i in 1:10
    res = run_es_bird(Nstep=Ngen, Npop=Npop, Sigma=sig)
    distances = res
    distance_histogram += distances
    plot!(distances)
end

current()

#####avec Npop = 200, Ngen = 500, sig = 0.1
#best initial: [0.19507200551351175, -0.08498603878178577, 0.9501283764216036, 0.20293169509199305, 0.9760144556650499]
#best initial fitness:0.29995407539330476
#best final: [-3.7801608774814435, -0.3807797572729434, -0.1904445735415997, -2.0321882891336522, -0.067457035171137]
#best final dist: 358.579500125548
# Out:
# best initial: [-2.0196617933566983, -0.057137185291252626, 0.35486450471058134, -0.6520841415788269, -0.9432325861614104]
# best initial fitness:1.1816
# best final: [-4.262476009411357, -0.34291403860393194, -0.34559314014559606, -2.0021044788861215, -0.05918998602340452]
# best final dist: 332.3018399999937
# best initial: [0.08926315355025272, 0.39791356650186954, 1.4264300834482202, 1.3928108078919625, 0.5364988409360552]
# best initial fitness:0.3024
# best final: [0.31750766149528487, 0.5808848178029545, 1.1477457167848455, 1.1628277995237373, 0.541579105972039]
# best final dist: 0.3024
# best initial: [0.0298744570508642, 0.22703258075209864, -0.8676369922535223, 1.3484598641592334, -0.8071318688525829]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [1.2234624694475804, 0.4346398128845853, -1.3749001207427765, 0.7462876510298021, 0.4849682030893657]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [-1.4037762150931512, -0.16872530174409683, -0.15284584615598293, 2.717580217043919, -0.37158102729699255]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [0.3756854082578808, 1.6479149357476481, 0.2402422316354342, -2.533111165228629, -0.01483299027640257]
# best initial fitness:0.9888
# best final: [-3.73068425690601, -0.288205383610013, -0.21426596166090484, -1.8040879323503618, -0.024721830270701184]
# best final dist: 332.3018399999937
# best initial: [-0.017883060600217455, 0.3318256265954642, 0.34197107121704085, 0.6085632845529562, -0.9265936232061797]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [-1.093185797548369, -1.126211382144137, -0.37121712741381313, -0.023486780680985753, 1.4212976734925127]
# best initial fitness:1.05264
# best final: [-4.079862816585721, -0.2998820822048591, -0.2741935387746401, -1.9391438624548305, -0.050579762847026706]
# best final dist: 332.3018399999937
# best initial: [0.2918336742997112, -0.34851239157971275, 0.11342193131784062, 0.4804682991393345, -1.1767601737574651]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [-0.40983251852149655, -1.01160647904542, -1.0335885238976903, -0.6641399138281461, 0.16993826116190183]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [0.6110792876717429, -0.7470254010342741, 0.3490423472306355, -0.20079524570602061, 0.8893129469756929]
# best initial fitness:1.05264
# InterruptException:
#
# Stacktrace:
#  [1] #step_birds#4(::Int64, ::Int64, ::Float64, ::Float64, ::typeof(step_birds), ::Array{Float64,1}) at ./In[9]:7
#  [2] #step_birds at ./In[10]:0 [inlined]
#  [3] #run_es_bird#7(::Int64, ::Int64, ::Float64, ::typeof(run_es_bird)) at ./In[10]:13
#  [4] (::var"#kw##run_es_bird")(::NamedTuple{(:Nstep, :Npop, :Sigma),Tuple{Int64,Int64,Float64}}, ::typeof(run_es_bird)) at ./none:0
#  [5] top-level scope at ./In[12]:14

# %%
histogram(distance_histogram)

# %% [markdown]
# # ___ ES __ 1 __ Cumulatif

# %%
function run_es_bird_cumu(;Nstep=500, Npop=100, Sigma=0.1)
    dim = 5
    
    best = randn(dim)
    #best = [-4.991793690362872, -1.0548510731723693, -0.46613776158659587, -2.281903602732939, -0.0011843804167953435]
    #best = [-3.7801608774814435, -0.3807797572729434, -0.1904445735415997, -2.0321882891336522, -0.067457035171137]
    
    
    println("best initial: ", best)
    first_fitness = evaluate_bird(best)
    println("best initial fitness:", first_fitness)
    cumul_fitness = first_fitness
    
    dist = zeros(Nstep)
    for i in 1:Nstep
        best = step_birds(best, dim=dim, npop=Npop, sigma=Sigma)

        if (objective(best) > cumul_fitness)
            cumul_fitness = objective(best)
        end
        
        dist[i] = cumul_fitness

    end
    println("best final: ", best)
    println("best final dist: ", objective(best))
    #best
    dist
end
# Out:
# run_es_bird_cumu (generic function with 1 method)

# %%
objective = evaluate_bird
Npop = 200
Ngen = 500
sig = 0.01

res = run_es_bird_cumu(Nstep=Ngen, Npop=Npop, Sigma=sig)
distances = res
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness pour l'ES")

for i in 1:5
    res = run_es_bird_cumu(Nstep=Ngen, Npop=Npop, Sigma=sig)
    distances = res
    plot!(distances)
end

current()

#####avec Npop = 200, Ngen = 500, sig = 0.1
#best initial: [0.19507200551351175, -0.08498603878178577, 0.9501283764216036, 0.20293169509199305, 0.9760144556650499]
#best initial fitness:0.29995407539330476
#best final: [-3.7801608774814435, -0.3807797572729434, -0.1904445735415997, -2.0321882891336522, -0.067457035171137]
#best final dist: 358.579500125548
# Out:
# best initial: [-0.12999891023565896, 0.5773504858366777, -1.42673190686473, 0.048802433121447046, 0.37697402433196303]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [0.9655021023402851, 0.3550572429521279, -0.729189688414229, -0.6028553306421803, -0.6896666809850567]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [-1.3957497048238536, 0.032122425010711934, -0.7421365069117807, -0.887569517257217, -1.3207777047458986]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# best initial: [1.1078256311188615, 0.164590115317092, -0.7614885726149636, 0.14825749576524216, -0.8119823340423034]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# InterruptException:
#
# Stacktrace:
#  [1] #step_birds#4(::Int64, ::Int64, ::Float64, ::Float64, ::typeof(step_birds), ::Array{Float64,1}) at ./In[9]:7
#  [2] #step_birds at ./In[14]:0 [inlined]
#  [3] #run_es_bird_cumu#8(::Int64, ::Int64, ::Float64, ::typeof(run_es_bird_cumu)) at ./In[14]:16
#  [4] (::var"#kw##run_es_bird_cumu")(::NamedTuple{(:Nstep, :Npop, :Sigma),Tuple{Int64,Int64,Float64}}, ::typeof(run_es_bird_cumu)) at ./none:0
#  [5] top-level scope at ./In[15]:14

# %% [markdown]
# #  _________________________ES________________

# %%
mutable struct Obj_es
    center::Bird
    best::Array{Bird}
end

function Obj_es(;mu=5)
    center = Bird()
    evaluate!(center)
    best = Array{Bird}(undef, mu)
    for i in eachindex(best)
        best[i] = Bird()
        evaluate!(best[i])
    end
    Obj_es(center, best)
end
# Out:
# Obj_es

# %%
function es_step!(obj::Obj_es; npop=50, sigma=0.01, alpha=sigma/10)
    x = obj.center
    best = obj.best
    
    mu = length(best)
    #dim = length(Bird)
    #println(mu)
    #println(dim)
    dim=5
    
    N = randn(npop,dim) 
    Pop = Array{Bird}(undef, npop)
    R = zeros(npop)
    for i in eachindex(N[1:npop-mu,1])
        Pop[i] = Bird()
        Pop[i].genes = x.genes .+ sigma .* N[i]
        evaluate!(Pop[i])
        R[i] = Pop[i].fitness
    end
    for i in eachindex(best)
        Pop[npop-mu+i] = Bird()
        Pop[npop-mu+i] = best[i]
        R[npop-mu+i] = best[i].fitness
        
        N[npop-mu+i,:] = (best[i].genes-x.genes)./sigma
    end
    
    #println("_____________________")
    #for i in eachindex(Pop)
    #    print("   ",Pop[i].fitness)
    #end
    
    Pop2 = sort(Pop, rev=true)
        
    #println("_____________________")
    #for i in eachindex(Pop2)
    #    print("   ",Pop2[i].fitness)
    #end
    #println("_____________________")
    
    #println("  R    :", R)
    
    A = (R .- mean(R)) ./ std(R)
    #println("____________________")
    #println(" A :", A)
    #println("____________________")
    #println(" N : ", N[:,1])
    
    test = dot(N[:, 1], A)
    #println(" test :", test)
    if isnan(test)
        println("failed")
    end
    mat = [dot(N[:, i], A) for i in 1:size(N, 2)]
    #println("mat : ", mat)
    #println(alpha/(npop * sigma) .* mat)
    w = alpha/(npop * sigma) .* mat#[dot(N[:, i], A) for i in 1:size(N, dim)]
    #println(" w : ", w)
    
    
    x.genes = x.genes .+ w #modification step: changing the center of gravity
    evaluate!(x)
    best = Array{Bird}(undef,mu)
    for i in eachindex(best)
        best[i] = Bird()
        best[i].genes = Pop2[i].genes
        best[i].fitness = Pop2[i].fitness
    end
    
    obj.center = x
    obj.best = best
end
# Out:
# es_step! (generic function with 1 method)

# %%
flappyX = Bird()
evaluate!(flappyX)
flappies = Array{Bird}(undef, 5)
for i in eachindex(flappies)
    flappies[i] = Bird()
    evaluate!(flappies[i])
end

obj = Obj_es()
flappyX = obj.center
flappies = obj.best

println(" X1 : ", flappyX)
println(" best1 : ", flappies)

#es_step!(flappyX, flappies, npop=10)
es_step!(obj,npop=10)
flappyX = obj.center
flappies = obj.best

println(" X2 : ", flappyX)
#println(" best2 : ", flappies)
println("_____________________best2____")
for i in eachindex(flappies)
    print("   ",flappies[i].fitness)
end

println("-------------______________--------------------------")

#es_step!(flappyX, flappies, npop=10)
es_step!(obj,npop=10)
flappyX = obj.center
flappies = obj.best

println(" X3 : ", flappyX)
#println(" best2 : ", flappies)
println("_____________________best3___")
for i in eachindex(flappies)
    print("   ",flappies[i].fitness)
end
# Out:
#  X1 : Bird([1.6213935831126234, -0.6019513808519503, -0.12894877838218174, -0.13215328679755997, -0.4475937241199456], 1.05264)
#  best1 : Bird[Bird([-1.1988613127733279, 1.2760729400256265, 0.4869943006791244, 0.17188961927936086, 0.8945207561721605], 0.3024), Bird([1.5258174384824645, -0.9563567765793389, 1.2094712303046384, 1.0642286642972207, -1.2823331959632915], 1.05264), Bird([0.6030164995434839, 0.6322093534892335, -0.19722294014259548, 1.7931545416233852, -1.570782799543538], 1.05264), Bird([-0.1164770569765715, 3.168089110777234, -0.043028748578362766, 1.0611033053162364, 1.4363305348071878], 0.3024), Bird([1.0186473202480841, 1.204318511008492, 0.8133384812795305, 0.34104746915655704, -1.1374767867002662], 0.5524800000000001)]
#  X2 : Bird([9.124733744135806, -11.147916150657613, -1.3935888771781235, -1.1771915460507474, -6.404398649222862], 1.05264)
# _____________________best2____
#    1.05264   1.05264   1.05264   1.05264   1.05264-------------______________--------------------------
# failed
#  X3 : Bird([NaN, NaN, NaN, NaN, NaN], 1.05264)
# _____________________best3___
#    1.05264   1.05264   1.05264   1.05264   1.05264

# %%
function run_es_bird(;Nstep=500, Npop=100, Sigma=0.1, mu=5)
    
    obj = Obj_es(mu=mu)
    
    println("initial X: ", obj.center)
    println("initial best: ", obj.best)
    
    dist = zeros(Nstep)
    for i in 1:Nstep
        es_step!(obj, npop=Npop, sigma=Sigma)
        #println("best: ", best)
        #println("best norm: ", norm(best))
        #println("dist max :" , objective(best))
        dist[i] = objective(obj.center.genes)
        #if dist[i]>300
         #   Sigma = 0.01
        #end
    end
    println("best final: ", obj.center)
    println("best final dist: ", objective(obj.center.genes))
    #best
    dist
end
# Out:
# run_es_bird (generic function with 1 method)

# %%
objective = evaluate_bird
Npop =00
Ngen = 1000
sigma = 0.1
mu = 5

distances = run_es_bird(Nstep=Ngen, Npop=Npop, Sigma=sigma, mu=mu )
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness pour l'ES")
max distances = 
for i in 1:5
    res = run_es_bird(Nstep=Ngen, Npop=Npop, Sigma=sigma, mu=mu )
    distances = res
    plot!(distances)
end

current()
# Out:
# initial X: Bird([-0.27759976218482274, 0.7959557523248117, 1.2424823445359794, -0.3562933257433826, 1.0789016030690874], 0.3024)
# initial best: Bird[Bird([-1.3506155660913146, 0.7661319509686371, -0.5457210749539163, 1.296562114034887, 0.09452901072292973], 1.05264), Bird([0.9850239231443619, 1.1080377196331894, -0.23296192695782994, 0.13534392910145973, -0.053923608770806965], 1.05264), Bird([1.0541897332202774, -0.3879173694751426, -1.6156177222026813, 0.8636582956693539, -1.163142288270139], 1.05264), Bird([0.6254135074307323, -0.6519824188576855, 0.608895986228394, -1.8007573112745945, -0.7710601770158689], 7.515280000000001), Bird([-0.5089296821920325, -1.1356868008487488, -0.6134557108449578, -1.9673791643874743, -0.3158981782675141], 1.6380000000000001)]
# BoundsError: attempt to access 0-element Array{Bird,1} at index [-4]
#
# Stacktrace:
#  [1] setindex! at ./array.jl:782 [inlined]
#  [2] #es_step!#10(::Int64, ::Float64, ::Float64, ::typeof(es_step!), ::Obj_es) at ./In[17]:21
#  [3] #es_step! at ./none:0 [inlined]
#  [4] #run_es_bird#13(::Int64, ::Int64, ::Float64, ::Int64, ::typeof(run_es_bird)) at ./In[19]:10
#  [5] (::var"#kw##run_es_bird")(::NamedTuple{(:Nstep, :Npop, :Sigma, :mu),Tuple{Int64,Int64,Float64,Int64}}, ::typeof(run_es_bird)) at ./none:0
#  [6] top-level scope at In[20]:6

# %% [markdown]
# # ____ ES ____ Cumulatif _____

# %%
function run_es_bird_cumul(;Nstep=500, Npop=100, Sigma=0.1, mu=5)
    
    obj = Obj_es(mu=mu)
    
    println("initial X: ", obj.center)
    println("initial best: ", obj.best)
    
    cumul_fitness = objective(obj.center.genes)
    
    dist = zeros(Nstep)
    for i in 1:Nstep
        es_step!(obj, npop=Npop, sigma=Sigma)

        if(objective(obj.center.genes) > cumul_fitness)
            cumul_fitness = objective(obj.center.genes)
        end
        dist[i] = cumul_fitness
        #if dist[i]>300
         #   Sigma = 0.01
        #end
    end
    println("best final: ", obj.center)
    println("best final dist: ", objective(obj.center.genes))
    #best
    dist
end
# Out:
# run_es_bird_cumul (generic function with 1 method)

# %%
objective = evaluate_bird
Npop = 150
Ngen = 700
sigma = 0.1
mu = 5

distances = run_es_bird_cumul(Nstep=Ngen, Npop=Npop, Sigma=sigma, mu=mu )
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness pour l'ES")


for i in 1:10
    res = run_es_bird_cumul(Nstep=Ngen, Npop=Npop, Sigma=sigma, mu=mu )
    distances = res
    plot!(distances)
end

current()
# Out:
# initial X: Bird([1.1027587285226674, -0.47883536097321705, 1.0608417235270964, 0.16353292822222065, 1.1100609866501714], 0.3024)
# initial best: Bird[Bird([0.6951767749540695, 1.1985739665998745, 0.7267389508961236, 0.5661371648448068, 0.9638024758489074], 0.3024), Bird([0.31930164183019166, 0.14171492679193856, 1.0412844971377915, 0.24753068998463346, -1.2323808825008786], 1.05264), Bird([-1.1448816507831459, -1.1299324639758213, 1.6146518436244972, -0.11908795079559115, 0.8938192484428906], 10.230160000000001), Bird([0.29111414627582244, 1.533402772206922, 1.0906267140931847, -1.1001993427621062, -0.618697502368914], 0.6108), Bird([-0.5739029881233788, 0.41755164911718873, -0.23708784620186624, 1.2929141629397187, -0.9626140804172247], 1.05264)]
# best final: Bird([-8.757949758248483, -1.4549561537896982, 0.5148900767276795, -0.6625909411395077, 0.1406448272375397], 17.20952)
# best final dist: 17.20952
# initial X: Bird([0.12592132427207176, -1.7708464966454123, -0.9008601295789075, 2.297583082728859, -0.42911871900025805], 1.05264)
# initial best: Bird[Bird([0.8779024436929959, -0.7937186608883497, 0.03988489853416182, -0.7417872772446791, -0.9853579492634141], 1.05264), Bird([0.3401827197859326, -2.323519315952626, -1.3772778477337082, 0.8513978016207379, -0.0754499735604951], 1.05264), Bird([-0.8947393226084549, 0.6001264356742213, -1.0824505362399812, -1.182122485218984, 1.4311829178119497], 1.93128), Bird([-0.2983136401136132, 0.09306273501917121, 0.842501096598546, 0.20229733838880976, -0.08637615970897074], 1.05264), Bird([-0.28652595938123676, -0.8727170809082555, 1.6751611708702623, -1.4979398420938566, -0.8906485996461914], 11.746080000000003)]
# InterruptException:
#
# Stacktrace:
#  [1] evaluate!(::Bird) at ./In[7]:3
#  [2] #es_step!#10(::Int64, ::Float64, ::Float64, ::typeof(es_step!), ::Obj_es) at ./In[17]:17
#  [3] #es_step! at ./In[21]:0 [inlined]
#  [4] #run_es_bird_cumul#14(::Int64, ::Int64, ::Float64, ::Int64, ::typeof(run_es_bird_cumul)) at ./In[21]:12
#  [5] (::var"#kw##run_es_bird_cumul")(::NamedTuple{(:Nstep, :Npop, :Sigma, :mu),Tuple{Int64,Int64,Float64,Int64}}, ::typeof(run_es_bird_cumul)) at ./none:0
#  [6] top-level scope at ./In[22]:15

# %% [markdown]
# # _______________________________ CMAES __________________________________________

# %%
mutable struct CMAES
    N::Int
    μ::Int
    λ::Int
    τ::Float64
    τ_c::Float64
    τ_σ::Float64
    population::Array{Array{Float64}}
    offspring::Array{Array{Float64}}
    F_μ::Array{Float64}
    F_λ::Array{Float64}
    C::Array{Float64}
    s::Array{Float64}
    s_σ::Array{Float64}
    σ::Float64
    E::Array{Float64}
    W::Array{Float64}
    x::Array{Float64}
end

# %%
function CMAES(;N=N_value, μ=mu, λ=lambda, τ=sqrt(N), τ_c=N^2, τ_σ=sqrt(N))
    x = randn(N)
    population = fill(x, µ)
    offspring = Array{Array{Float64}}(undef, λ)
    F_µ = Inf .* ones(µ)
    F_λ = Inf .* ones(λ)
    C = Array(Diagonal{Float64}(I, N))
    s = zeros(N)
    s_σ = zeros(N)
    σ = 1.0
    E = zeros(N, λ)
    W = zeros(N, λ);
    CMAES(N, μ, λ, τ, τ_c, τ_σ, population, offspring, F_µ, F_λ, C, s, s_σ, σ, E, W, x)
end
# Out:
# CMAES

# %%
function step_cmaes!(c::CMAES; obj=objective)
    # L1
    sqrt_c = cholesky((c.C + c.C') / 2.0).U
    for i in 1:c.λ
        c.E[:,i] = randn(c.N)
        c.W[:,i] = c.σ * (sqrt_c * c.E[:,i])
        c.offspring[i] = c.x + c.W[:,i]
        c.F_λ[i] =  obj(c.offspring[i])
    end    
    # Select new parent population
    idx = sortperm(c.F_λ)[1:c.μ]
    for i in 1:c.μ
        c.population[i] = c.offspring[idx[i]]
        c.F_μ[i] = c.F_λ[idx[i]]
    end    
    # L2
    w = vec(mean(c.W[:,idx], dims=2))##################################################
    c.x += w
    # L3
    c.s = (1.0 - 1.0/c.τ)*c.s + (sqrt(c.μ/c.τ * (2.0 - 1.0/c.τ))/c.σ)*w   
    # L4
    c.C = (1.0 - 1.0/c.τ_c).*c.C + (c.s./c.τ_c)*c.s'    
    # L5
    ɛ = vec(mean(c.E[:,idx], dims=2))##################################################
    c.s_σ = (1.0 - 1.0/c.τ_σ)*c.s_σ + sqrt(c.μ/c.τ_σ*(2.0 - 1.0/c.τ_σ))*ɛ    
    # L6
    c.σ = c.σ*exp(((c.s_σ'*c.s_σ)[1] - c.N)/(2*c.N*sqrt(c.N)))
    
    if c.σ>1.0
        c.σ = 1.0
    end
    #if c.σ<0.0005
    #    c.σ = 0.0005
    #end
    
    c
end
# Out:
# step_cmaes! (generic function with 1 method)

# %%
function objective_cma(g::Array{Float64})
    -1*evaluate_bird(g)
end

N_value = 5
mu = 5
lambda = 10
c = CMAES()
println(c.population[1])
println(evaluate_bird(c.population[1]))
step_cmaes!(c, obj=objective_cma)
println(c.population[1])
println(evaluate_bird(c.population[1]))
step_cmaes!(c, obj=objective_cma)
println(c.population[1])
println(evaluate_bird(c.population[1]))
step_cmaes!(c, obj=objective_cma)
println(c.population[1])
println(evaluate_bird(c.population[1]))
# Out:
# [-0.1145243572617352, 0.029960422939144415, -0.4482182052160783, 0.0071556589795578425, 0.5189012638187825]
# 1.05264
# [-0.803640054736445, -0.23843895310020646, -0.5569163477196154, -0.9862682141810503, 1.1962162756699977]
# 6.153600000000001
# [0.016192580507143062, 0.05959941866351104, -0.8618673203191092, -1.133190117704229, 1.5190891683202374]
# 1.70424
# [-0.44157965974665103, -0.2951810204908154, 0.652840031949818, -1.0509919072456178, 0.864515567424386]
# 2.45472

# %%
function run_cmaes(;Nstep=500, mu=5, lambda=10)
    c = CMAES()
    sigs = zeros(Nstep)
    dist = zeros(Nstep)
    for i in 1:Nstep
        step_cmaes!(c,obj=objective_cma)
        sigs[i] = c.σ
        dist[i] = evaluate_bird(c.x)
    end
    [c.x, sigs, dist]
end
# Out:
# run_cmaes (generic function with 1 method)

# %%
Nstep =500
mu = 30
lambda = 50

flappy_boss = Bird()
res = run_cmaes(Nstep=Nstep, mu=mu, lambda=lambda)
flappy_boss.genes = res[1]
evaluate!(flappy_boss)
println(flappy_boss)

sigs = res[2]
p1 = plot(sigs)
xaxis!("ngen")
yaxis!("sig")

dist = res[3]
p2 = plot(dist)
xaxis!("ngen")
yaxis!("dist")

plot(p1, p2, layout=(2,1))

#Bird([-4.991793690362872, -1.0548510731723693, -0.46613776158659587, -2.281903602732939, -0.0011843804167953435], 332.30109957667014)
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] #step_cmaes!#16(::typeof(objective_cma), ::typeof(step_cmaes!), ::CMAES) at ./In[25]:8
#  [2] #step_cmaes! at ./none:0 [inlined]
#  [3] #run_cmaes#17(::Int64, ::Int64, ::Int64, ::typeof(run_cmaes)) at ./In[27]:6
#  [4] (::var"#kw##run_cmaes")(::NamedTuple{(:Nstep, :mu, :lambda),Tuple{Int64,Int64,Int64}}, ::typeof(run_cmaes)) at ./none:0
#  [5] top-level scope at In[28]:6

# %%
Nrun=1
Nstep = 500
mu=25
lambda= 50

distances = zeros(Nstep, Nrun)
birds = Array{Bird}(undef, Nrun)
for i in 1:Nrun
    res = run_cmaes(Nstep=Nstep, mu=mu, lambda=lambda)
    distances[:,i] = res[3]
    birds[i] = Bird()
    birds[i].genes = res[1]
    evaluate!(birds[i])
end

println(birds)
plot(distances)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness avec CMA-ES")
# Out:
# Bird[Bird([0.727235965189507, -0.4965369234035623, -0.9663138549672016, 1.4086351717823271, -0.8659489702199551], 1.05264)]

# %% [markdown]
# # ____ CMA-ES Cumulatif ____

# %%
function run_cmaes_cumul(;Nstep=500, mu=5, lambda=10)
    c = CMAES()
    sigs = zeros(Nstep)
    dist = zeros(Nstep)
    fitness_cumu = 0
    
    for i in 1:Nstep
        step_cmaes!(c,obj=objective_cma)
        sigs[i] = c.σ
        if(evaluate_bird(c.x) > fitness_cumu)
            fitness_cumu = evaluate_bird(c.x)
        end
        dist[i] = fitness_cumu
    end
    [c.x, sigs, dist]
end
# Out:
# run_cmaes_cumul (generic function with 1 method)

# %%
Nrun=10
Nstep = 100
mu=25
lambda= 50

distances = zeros(Nstep, Nrun)
birds = Array{Bird}(undef, Nrun)
for i in 1:Nrun
    res = run_cmaes_cumul(Nstep=Nstep, mu=mu, lambda=lambda)
    distances[:,i] = res[3]
    birds[i] = Bird()
    birds[i].genes = res[1]
    evaluate!(birds[i])
end

println(birds)
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness avec CMA-ES")
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] #step_cmaes!#16(::typeof(objective_cma), ::typeof(step_cmaes!), ::CMAES) at ./In[25]:8
#  [2] #step_cmaes! at ./none:0 [inlined]
#  [3] #run_cmaes_cumul#18(::Int64, ::Int64, ::Int64, ::typeof(run_cmaes_cumul)) at ./In[30]:8
#  [4] (::var"#kw##run_cmaes_cumul")(::NamedTuple{(:Nstep, :mu, :lambda),Tuple{Int64,Int64,Int64}}, ::typeof(run_cmaes_cumul)) at ./none:0
#  [5] top-level scope at ./In[31]:9

# %% [markdown]
# # Comparaison des deux algorithmes

# %%
### ES MU+LAMBDA #####

objective = evaluate_bird
Nrun=10
Npop = 150
lambda = 50
Ngen =00
Ngen = 200
sigma = 0.1
mu = 5

distances = run_es_bird_cumul(Nstep=Ngen, Npop=Npop, Sigma=sigma, mu=mu )
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness pour l'ES")


for i in 1:NRUN
    res = run_es_bird_cumul(Nstep=Ngen, Npop=Npop, Sigma=sigma, mu=mu )
    distances = res
    plot!(distances)
end

current()


#### CMAES #######



Nstep = 100
mu=25
lambda= 50

distances = zeros(Nstep, Nrun)
birds = Array{Bird}(undef, Nrun)
for i in 1:Nrun
    res = run_cmaes_cumul(Nstep=Nstep, mu=mu, lambda=lambda)
    distances[:,i] = res[3]
    birds[i] = Bird()
    birds[i].genes = res[1]
    evaluate!(birds[i])
end

println(birds)
plot(distances,legend=:outertopright)
xaxis!("Ngen")
yaxis!("distance")
title!("Evolution de la fitness avec CMA-ES")
# Out:
# initial X: Bird([-0.6784604984602316, -0.8158854158945053, 0.029829323244530182, 1.2308500462542287, -0.37438558227603], 1.05264)
# initial best: Bird[Bird([-0.6453773118170457, 1.0247582616969606, -1.6057899697696925, 0.2258335283290274, -0.5172812111400217], 1.05264), Bird([0.9890990748206913, -2.1740040414558592, -0.6801697178701166, 1.2098820986364212, 1.204704421841769], 1.05264), Bird([0.19030088411643328, 0.47398403701005054, 0.8387989263835962, 0.25429574551797757, -0.15784127740275256], 0.3024), Bird([0.1693406140769572, 0.35368580766539454, 1.58573079174624, 0.7048858793810174, -0.22030065531191506], 0.3024), Bird([-0.39459692483146686, 2.100383580675507, -2.660375120439583, -1.1151362789062438, 0.5314270911276314], 1.05264)]
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: Bird([NaN, NaN, NaN, NaN, NaN], 1.05264)
# best final dist: 1.05264
# UndefVarError: NRUN not defined
#
# Stacktrace:
#  [1] top-level scope at ./In[32]:17

# %% [markdown]
# # Histogramme

# %%
function histogram_birds(method::Function, thresholds::Array{Int}, nTests::Int)
    list_res = zeros(nTests)
    max_found = 0
    for i in 1:nTests
        println("Test n.",i," started ...")
        res = method()
        list_res[i] = res
        if res>max_found
            max_found=res
        end
    end
    println("Plotting ... max found = ", max_found)
    arr = zeros(length(thresholds)+2)
    arr[1] = 0
    for k in 1:length(thresholds)
        arr[k+1]=thresholds[k]
    end
    arr[length(thresholds)+2] = max_found+1
    histogram(list_res, bins=arr, ylim=(0,0.9*nTests))
end
# Out:
# histogram_birds (generic function with 1 method)

# %%
function histogram_birds()
    histogram_birds(method, thresholds, nTests)
end
# Out:
# histogram_birds (generic function with 2 methods)

# %%
function random_unif(limit::Float64)
    rand()*limit
end

function random_unif()
    random_unif(500.0)
end
# Out:
# random_unif (generic function with 2 methods)

# %%
method = random_unif # l'algo doit renvoyer la distance en fin d'évolution
thresholds = [10, 80, 260] # les délimitations des cases où ranger les résultats
nTests = 20 # nombre de tests à effectuer

histogram_birds()
# Out:
# Test n.1 started ...
# Test n.2 started ...
# Test n.3 started ...
# Test n.4 started ...
# Test n.5 started ...
# Test n.6 started ...
# Test n.7 started ...
# Test n.8 started ...
# Test n.9 started ...
# Test n.10 started ...
# Test n.11 started ...
# Test n.12 started ...
# Test n.13 started ...
# Test n.14 started ...
# Test n.15 started ...
# Test n.16 started ...
# Test n.17 started ...
# Test n.18 started ...
# Test n.19 started ...
# Test n.20 started ...
# Plotting ... max found = 474.0089579148633

# %%
function run_es_bird_fitness()
    Nstep= 250
    Npop= 200
    Sigma=0.1
    dim = 5
    best = randn(dim)
    #best = [-4.991793690362872, -1.0548510731723693, -0.46613776158659587, -2.281903602732939, -0.0011843804167953435]
    #best = [-3.7801608774814435, -0.3807797572729434, -0.1904445735415997, -2.0321882891336522, -0.067457035171137]
    
    println("best initial: ", best)
    first_fitness = evaluate_bird(best)
    println("best initial fitness:", first_fitness)
    
    dist = zeros(Nstep)
    for i in 1:Nstep
        best = step_birds(best, dim=dim, npop=Npop, sigma=Sigma)
        #println("best: ", best)
        #println("best norm: ", norm(best))
        #println("dist max :" , objective(best))
        dist[i] = objective(best)
        #if dist[i]>300
         #   Sigma = 0.01
        #end
    end
    println("best final: ", best)
    println("best final dist: ", objective(best))
    #best
    dist[Nstep]
end
# Out:
# run_es_bird_fitness (generic function with 1 method)

# %%
method = run_es_bird_fitness # l'algo doit renvoyer la distance en fin d'évolution
thresholds = [10, 80, 260] # les délimitations des cases où ranger les résultats
nTests = 30 # nombre de tests à effectuer

histogram_birds()
# Out:
# Test n.1 started ...
# best initial: [-0.4903113558252915, -1.3022320476252358, -0.7399991530894217, -0.6640799067904163, -0.6985445730511292]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# Test n.2 started ...
# best initial: [-1.1657991185671877, -1.3796249362193787, 0.5285536540068728, -0.171510613319169, 0.9487220874129361]
# best initial fitness:15.861280000000004
# best final: [-3.4199520105943906, -0.2267852404663941, -0.1538702954482693, -1.6998442740376356, 0.003293628092365158]
# best final dist: 330.2594399999938
# Test n.3 started ...
# best initial: [-0.07374790712446973, -0.5026235472663275, 0.5059570836751156, 1.7060102885376753, -1.7684756494383884]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# Test n.4 started ...
# best initial: [0.5736505512585661, -1.4829805141719268, -0.3333071144874046, -0.10157704162267689, 0.9488497378172576]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# Test n.5 started ...
# best initial: [-0.7500054163643208, 0.5820694150032978, 0.6884722081019253, -0.1025587677340832, 0.13688744994492896]
# best initial fitness:2.15504
# best final: [-2.834435098708748, -0.2824038541364691, 0.3452487279685897, -1.7896739185686144, -0.04894778615355973]
# best final dist: 185.8537599999983
# Test n.6 started ...
# best initial: [-1.0219886125078592, 0.34687201711313626, -0.4538349705505313, -1.7212789818685583, 0.30472995383175827]
# best initial fitness:15.184800000000003
# best final: [-3.404587658558814, -0.2034511179204673, -0.1704078725152192, -1.7096476852773743, -0.01222082513715226]
# best final dist: 330.2594399999938
# Test n.7 started ...
# best initial: [-0.39941197103602016, 0.9986172329615788, -1.8610948889517043, 0.5101624618440255, 0.2284174525798755]
# best initial fitness:1.05264
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# failed
# best final: [NaN, NaN, NaN, NaN, NaN]
# best final dist: 1.05264
# Test n.8 started ...
# best initial: [0.09470850354565138, -0.8415865226415261, 0.39266468142951033, -0.8978573265006057, -0.057060007571658924]
# best initial fitness:1.68216
# best final:

# %%
function run_cmaes_fitness()
    Nstep=250
    mu=5
    lambda=200
    c = CMAES()
    sigs = zeros(Nstep)
    dist = zeros(Nstep)
    for i in 1:Nstep
        step_cmaes!(c,obj=objective_cma)
        sigs[i] = c.σ
        dist[i] = evaluate_bird(c.x)
    end
    #[c.x, sigs, dist]
    dist[Nstep]
end

# %%
method = run_cmaes_fitness # l'algo doit renvoyer la distance en fin d'évolution
thresholds = [10, 80, 260] # les délimitations des cases où ranger les résultats
nTests = 20 # nombre de tests à effectuer

histogram_birds()

# %% [markdown]
# # Petits tests bêtes pour comprendre la base

# %%
pop = Array{Bird}(undef, 5)

for i in eachindex(pop)
    pop[i] = Bird()
    evaluate!(pop[i])
end
println(pop)

pop2 = sort(pop, rev=true)

# %%
N = ones(3,2)
println(N)
S = [5,10]
#println(N.*S)
#println(S.*N)
#println(dot(S,N))
#println(dot(N,S))
#res1 = [dot(N[:, i]) for i in 1:size(N, 2)]
#println("res1 ",res1)

res2 = reshape([N[i,:].*S for i in 1:3],3,2)
println("res2 ",res2)

x = [2.0,4.0]
P = repeat(x,1,3)
println(P')

println(P'.+N)
println(P'.+res2)

# %%
list = [41,42,444,569,1,-3]
a = 0
for i in list
    println("i:",i)
    if (max(a,i)!= a)
        a = i
        println("new a:",a)
    end
end
a
